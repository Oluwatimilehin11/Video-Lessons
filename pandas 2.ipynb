# %% [markdown]
# ### Group by Methods abd Aggregating

# %%
import pandas as pd
import numpy as np

# %%
animals = pd.read_csv("C:\\Users\\phera\\Desktop\\datasets\\animal_center.csv")
animals
# Out:
#     animal_id            name                 datetime  \
# 0     A845461             Max  2021-10-31T18:56:00.000
# 1     A845367  Juice Box "Jb"  2021-10-31T17:51:00.000
# 2     A844571           Saint  2021-10-31T17:28:00.000
# 3     A684713         Magneto  2021-10-31T16:55:00.000
# 4     A845471          845471  2021-10-31T15:48:00.000
# ..        ...             ...                      ...
# 995   A843739             NaN  2021-10-06T15:08:00.000
# 996   A843736             NaN  2021-10-06T15:08:00.000
# 997   A843737             NaN  2021-10-06T15:08:00.000
# 998   A843371             NaN  2021-10-06T15:07:00.000
# 999   A843735             NaN  2021-10-06T15:07:00.000
#
#                    monthyear            date_of_birth     outcome_type  \
# 0    2021-10-31T18:56:00.000  2020-05-01T00:00:00.000         Adoption
# 1    2021-10-31T17:51:00.000  2017-10-28T00:00:00.000  Return to Owner
# 2    2021-10-31T17:28:00.000  2020-10-17T00:00:00.000         Adoption
# ...

# %%
animals.head()
# Out:
#   animal_id            name                 datetime                monthyear  \
# 0   A845461             Max  2021-10-31T18:56:00.000  2021-10-31T18:56:00.000
# 1   A845367  Juice Box "Jb"  2021-10-31T17:51:00.000  2021-10-31T17:51:00.000
# 2   A844571           Saint  2021-10-31T17:28:00.000  2021-10-31T17:28:00.000
# 3   A684713         Magneto  2021-10-31T16:55:00.000  2021-10-31T16:55:00.000
# 4   A845471          845471  2021-10-31T15:48:00.000  2021-10-31T15:48:00.000
#
#              date_of_birth     outcome_type animal_type sex_upon_outcome  \
# 0  2020-05-01T00:00:00.000         Adoption         Dog      Intact Male
# 1  2017-10-28T00:00:00.000  Return to Owner         Dog    Neutered Male
# 2  2020-10-17T00:00:00.000         Adoption         Dog    Neutered Male
# 3  2014-06-05T00:00:00.000         Adoption         Cat    Neutered Male
# 4  2021-10-21T00:00:00.000         Transfer         Cat    Intact Female
#
# ...

# %%
animals = ('animal_outcome', ('outcome_type'))

# %%
# same goes for multi index groupbys

animal_outcome = animals.groupby(['animal_type', 'outcome_type'])
animal_outcome.groups
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f5b53447b276> in <module>
#       1 # same goes for multi index groupbys
#       2
# ----> 3 animal_outcome = animals.groupbys(['animal_type', 'outcome_type'])
#       4 animal_outcome.groups
#
# AttributeError: 'tuple' object has no attribute 'groupbys'

# %%
animal_outcome.groups.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d2043ac04dfa> in <module>
# ----> 1 animal_outcome.groups.keys()
#
# NameError: name 'animal_outcome' is not defined

# %%
animal_outcome.get_group(('Cat', 'Adoption'))
# Out:
#     animal_id       name                 datetime                monthyear  \
# 3     A684713    Magneto  2021-10-31T16:55:00.000  2021-10-31T16:55:00.000
# 5     A843414      *Mary  2021-10-31T15:28:00.000  2021-10-31T15:28:00.000
# 6     A843415     *Sarah  2021-10-31T15:28:00.000  2021-10-31T15:28:00.000
# 23    A845156        Biz  2021-10-30T17:14:00.000  2021-10-30T17:14:00.000
# 26    A843892    *Pepper  2021-10-30T16:59:00.000  2021-10-30T16:59:00.000
# ..        ...        ...                      ...                      ...
# 985   A841362      Sealy  2021-10-06T16:05:00.000  2021-10-06T16:05:00.000
# 986   A843390    A843390  2021-10-06T15:57:00.000  2021-10-06T15:57:00.000
# 987   A843391  10A843391  2021-10-06T15:57:00.000  2021-10-06T15:57:00.000
# 988   A837441      Willy  2021-10-06T15:52:00.000  2021-10-06T15:52:00.000
# 991   A835742      *Thor  2021-10-06T15:22:00.000  2021-10-06T15:22:00.000
#
# ...

# %%
animal_outcome.first()
# Out:
#                             animal_id            name  \
# animal_type outcome_type
# Bird        Adoption          A842650            None
#             Transfer          A844575        Sunshine
# Cat         Adoption          A684713         Magneto
#             Died              A845014         A845014
#             Disposal          A843514            None
#             Euthanasia        A844992         A844496
#             Return to Owner   A598832         Boogers
#             Rto-Adopt         A844359        Mr. Mans
#             Transfer          A845471          845471
# Dog         Adoption          A845461             Max
#             Died              A771583          Pirata
#             Disposal          A844932            None
#             Euthanasia        A845022            Mila
#             Missing           A840024        *A840024
#             Return to Owner   A845367  Juice Box "Jb"
#             Rto-Adopt         A814670           Falco
# ...

# %%
animal_outcome.last()
# Out:
#                             animal_id        name                 datetime  \
# animal_type outcome_type
# Bird        Adoption          A842650        None  2021-10-07T09:53:00.000
#             Transfer          A843646     A843646  2021-10-14T16:43:00.000
# Cat         Adoption          A835742       *Thor  2021-10-06T15:22:00.000
#             Died              A844632     A844632  2021-10-21T18:12:00.000
#             Disposal          A843514        None  2021-10-06T16:09:00.000
#             Euthanasia        A844049     A844049  2021-10-11T14:01:00.000
#             Return to Owner   A843399       Simba  2021-10-06T17:41:00.000
#             Rto-Adopt         A844310       Lucky  2021-10-18T15:58:00.000
#             Transfer          A843735     *Nettle  2021-10-06T15:07:00.000
# Dog         Adoption          A760095        Rory  2021-10-06T15:24:00.000
#             Died              A832522       Lilly  2021-10-12T08:05:00.000
# ...

# %%
animals.groupby('animal_type').mean()[animals['animal_type']['Dog']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-352503d46e6a> in <module>
# ----> 1 animals.groupby('animal_type').mean()[animals['animal_type']['Dog']]
#
# AttributeError: 'tuple' object has no attribute 'groupby'

# %%
animals.groupby(['animal_type']).get_group(('Cat', 'Transfer')).describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-772af0dc7f5b> in <module>
# ----> 1 animals.groupby(['animal_type']).get_group(('Cat', 'Transfer')).describe()
#
# AttributeError: 'tuple' object has no attribute 'groupby'

# %% [markdown]
# ### More pandas

# %%
import numpy as np
import pandas as pd
animals =pd.read_csv("C:\\Users\\phera\\Desktop\\datasets\\Austin_Animal_Center_Outcomes.csv")
animals.head()
# Out:
#   Animal ID   Name                DateTime               MonthYear  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  05/08/2019 06:20:00 PM
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  07/18/2018 04:02:00 PM
# 2   A821648    NaN  08/16/2020 11:38:00 AM  08/16/2020 11:38:00 AM
# 3   A720371  Moose  02/13/2016 05:59:00 PM  02/13/2016 05:59:00 PM
# 4   A674754    NaN  03/18/2014 11:47:00 AM  03/18/2014 11:47:00 AM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    05/02/2017    Rto-Adopt             NaN         Cat    Neutered Male
# 1    07/12/2017     Adoption             NaN         Dog    Neutered Male
# 2    08/16/2019   Euthanasia             NaN       Other          Unknown
# 3    10/08/2015     Adoption             NaN         Dog    Neutered Male
# 4    03/12/2014     Transfer         Partner         Cat      Intact Male
#
#   Age upon Outcome                               Breed              Color
# ...

# %% [markdown]
# ### Reshaping a Dataframe

# %% [markdown]
# ### .pivot()

# %%
animals.pivot(values= ('Age upon Outcome'), columns = ('Animal Type')).head()
# Out:
# Animal Type Bird      Cat       Dog Livestock   Other
# 0            NaN  2 years       NaN       NaN     NaN
# 1            NaN      NaN    1 year       NaN     NaN
# 2            NaN      NaN       NaN       NaN  1 year
# 3            NaN      NaN  4 months       NaN     NaN
# 4            NaN   6 days       NaN       NaN     NaN

# %%
animals.groupby(by=['Outcome Type', 'Sex upon Outcome']).agg(len)
# Out:
#                                   Animal ID   Name  DateTime  MonthYear  \
# Outcome Type    Sex upon Outcome
# Adoption        Intact Female          1305   1305      1305       1305
#                 Intact Male            1134   1134      1134       1134
#                 Neutered Male         29224  29224     29224      29224
#                 Spayed Female         28517  28517     28517      28517
#                 Unknown                 187    187       187        187
# Died            Intact Female           316    316       316        316
#                 Intact Male             395    395       395        395
#                 Neutered Male            99     99        99         99
#                 Spayed Female            92     92        92         92
#                 Unknown                 354    354       354        354
# Disposal        Intact Female            36     36        36         36
#                 Intact Male              59     59        59         59
# ...

# %%
animals.pivot_table(index='Outcome Type', columns = 'Sex upon Outcome', aggfunc=len)
# Out:
#                  Age upon Outcome                                          \
# Sex upon Outcome    Intact Female Intact Male Neutered Male Spayed Female
# Outcome Type
# Adoption                   1305.0      1134.0       29224.0       28517.0
# Died                        316.0       395.0          99.0          92.0
# Disposal                     36.0        59.0           7.0           6.0
# Euthanasia                 1073.0      1275.0         838.0         521.0
# Missing                      20.0        26.0           7.0          14.0
# Relocate                      1.0         NaN           1.0           3.0
# Return to Owner            2705.0      3988.0        8938.0        6532.0
# Rto-Adopt                    28.0        38.0         446.0         289.0
# Transfer                  11011.0     10017.0        7298.0        6202.0
#
#                              Animal ID                            \
# Sex upon Outcome Unknown Intact Female Intact Male Neutered Male
# ...
