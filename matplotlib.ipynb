# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas # mport FigureCanvas
from matplotlib.figure import Figure
fig = Figure()  
canvas = FigureCanvas(fig)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np
x = np.random.randn(10000)
ax = fig.add_subplot(111)
ax.hist(x,100)
# Out:
# (array([  2.,   2.,   2.,   3.,   1.,   2.,   5.,   4.,   9.,   8.,   8.,
#          11.,  12.,  16.,  20.,  20.,  31.,  28.,  46.,  42.,  59.,  49.,
#          58.,  88.,  77.,  93.,  96., 111., 137., 141., 143., 161., 164.,
#         217., 182., 206., 225., 228., 231., 247., 281., 262., 280., 269.,
#         312., 278., 288., 283., 273., 249., 247., 282., 262., 263., 252.,
#         251., 238., 213., 213., 176., 177., 190., 132., 135., 116., 124.,
#         105.,  83.,  70.,  66.,  70.,  54.,  49.,  41.,  44.,  38.,  28.,
#          26.,  16.,  16.,  10.,   8.,  12.,   6.,   5.,   5.,   3.,   2.,
#           3.,   5.,   0.,   1.,   0.,   0.,   2.,   0.,   0.,   0.,   0.,
#           1.]),
#  array([-3.37750759, -3.30461381, -3.23172003, -3.15882625, -3.08593246,
#         -3.01303868, -2.9401449 , -2.86725112, -2.79435734, -2.72146356,
#         -2.64856977, -2.57567599, -2.50278221, -2.42988843, -2.35699465,
# ...

# %%
ax.set_title('Normal distribution with $\mu=0, \sigma=1$')
fig.savefig('matplotlib_histogram.png')

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(10000)
plt.hist(x, 100)
plt.title('Normal distribution with $\mu=0, \sigma=1$')
plt.savefig('matplotlib_histogram.png')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(5,5, 'o')
plt.show()

# %%
plt.plot(5,5,'o')

plt.ylabel("Y")
plt.xlabel("X")
plt.title(" Plotting Example")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### BASIC GRAPH

# %%
x = [0,1,2,3,4,]
y = [0,2,4,6,8,]

# resize your graph
plt.figure(figsize=(5,3), dpi=200)

#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle= '--', markersize= 10, markeredgecolor='blue')
# use shorthand notation
#fmt = '[color][marker][line]'
plt.plot(x,y, 'g^--',  label='2x')

## line number 2
x2 = np.arange(0,4.5,0.5)
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')
plt.plot(x2[5:], x2[5:]**2, 'r--')


plt.title('our First Graph', fontdict={'fontname': 'Comic Sans MS'})
labels =["A","B", "C"]
values =[1,4,2]

bars = plt.bar(labels,values)

patterns = ['/', 'o', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

# bars[0].set_hatch('/')
# bars[1].set_hatch('o')
# bars[2].set_hatch('*')




plt.figure(figsize=(6,4))

plt.savefig('mybarchart.png', dpi=300)
plt.show()

# %% [markdown]
# ### LINE GRAPH

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
gas = pd.read_csv("C:\\Users\\phera\\Desktop\\datasets\\gas_prices.csv")
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.title('Gas Prices over time (in USD)', fontdict= {'fontweight' :'bold', 'fontsize': 18})


plt.plot(gas.Year, gas.USA, 'b.-',label= 'USA',)
plt.plot(gas.Year, gas.Canada, 'r.-', label= 'Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label= 'South Korea')
plt.plot(gas.Year, gas.Australia, 'y.-', label= 'Australia')

#countries_to_look_at =['Australia', 'USA', 'Canada', 'South Korea']
#for country in gas:
#    if country in countries_to_look_at :
#        plt.plot(gas.Year, gas[country], marker= '.' )



print(gas.Year [::3])
plt.xticks(gas.Year [::3].tolist()+[2011])

plt.xlabel('Year')
plt.ylabel('US Dollars')


plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()
# Out:
# 0     1990
# 3     1993
# 6     1996
# 9     1999
# 12    2002
# 15    2005
# 18    2008
# Name: Year, dtype: int64

# %% [markdown]
# ### LOAD FIFA DATA

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fifa_data= pd.read_csv("C:\\Users\\phera\\Desktop\\datasets\\fifa_data.csv")
fifa_data
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...
